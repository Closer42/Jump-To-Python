# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Jump-To-Python
# Out:
# /content/drive/MyDrive/Jump-To-Python

# %%
# !git config --global user.email 'jungwoo6910@gmail.com'
# !git config --global user.name 'Closer42'

# %%
# !git add Untitled2.ipynb
